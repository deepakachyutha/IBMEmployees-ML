# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

employee = pd.read_csv('C:\IBMEmployees-ML\Dataset\IBM-HR-Employee-Attrition-Encoded.csv')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18560\2285050945.py:5: SyntaxWarning: invalid escape sequence '\I'
#   employee = pd.read_csv('C:\IBMEmployees-ML\Dataset\IBM-HR-Employee-Attrition-Encoded.csv')

# %%
employee.groupby('Department')['Attrition'].mean().plot(kind='bar')
plt.title("Attrition Rate by Department")
plt.xlabel("Department")
plt.ylabel("Attrition Rate")
plt.show()
